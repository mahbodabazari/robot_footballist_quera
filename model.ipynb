# %%
import pandas as pd
import numpy as np
import torch
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import torch.nn as nn
import torch.nn.functional as F
from PIL import Image
from torch import optim
from torch.utils.data import DataLoader, Dataset, Subset
from torchvision import transforms, models, datasets
from glob import glob
import os
from sklearn.model_selection import train_test_split
import random
from transformers import CLIPVisionModel
import albumentations as A
from albumentations.pytorch import ToTensorV2
from tqdm import tqdm
import time
import cv2
from torchvision.datasets import ImageFolder
from torchinfo import summary
import re
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
base_path = r"F:\deep_learning\robot_footballista_quera\train"
folders = ["Defender", "Forward", "Goalkeeper", "Midfielder"]
samples_per_folder = 5

fig, axes = plt.subplots(4, 5, figsize=(15, 12))

for i, folder in enumerate(folders):
    folder_path = os.path.join(base_path, folder)
    image_files = [f for f in os.listdir(folder_path) if f.endswith(('.png', '.jpg', '.jpeg'))]
    
    selected_images = random.sample(image_files, min(samples_per_folder, len(image_files)))
    
    for j, img_name in enumerate(selected_images):
        img_path = os.path.join(folder_path, img_name)
        img = Image.open(img_path)
        axes[i, j].imshow(img)
        axes[i, j].set_title(f"{folder} {j+1}")
        axes[i, j].axis('off')  

plt.tight_layout()
plt.show()

# %%
transform = A.Compose([
    A.Resize(height=256, width=256),              
    A.CenterCrop(height=224, width=224),        
    A.Normalize(                                  
        mean=(0.48145466, 0.4578275, 0.40821073),
        std=(0.26862954, 0.26130258, 0.27577711)
    ),
    ToTensorV2()                                  
])

class FootballistaDataset(Dataset):
    def __init__(self, base_path, transform=None):
        self.base_path = base_path
        self.classes = ['Defender', 'Forward', 'Goalkeeper', 'Midfielder']
        self.image_paths = []
        self.labels = []
        self.transform = transform
        self._load_paths()

    def _load_paths(self):
        for idx, cls in enumerate(self.classes):
            cls_path = os.path.join(self.base_path, cls)
            for file in os.listdir(cls_path):
                if file.endswith(('.jpg', '.png', '.jpeg')):
                    self.image_paths.append(os.path.join(cls_path, file))
                    self.labels.append(idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        path = self.image_paths[idx]
        label = self.labels[idx]
        image = np.array(Image.open(path).convert("RGB"))
        if self.transform:
            image = self.transform(image=image)["image"]
        label = torch.tensor(label, dtype=torch.long)
        return image, label
    
def split_dataset(dataset, train_size=0.8):
    indices = list(range(len(dataset)))
    train_indices, test_indices = train_test_split(
        indices, train_size=train_size, stratify=dataset.labels, random_state=42
    )
    train_dataset = Subset(dataset, train_indices)
    val_dataset = Subset(dataset, test_indices)
    return train_dataset, val_dataset

# %%
base_path = r"F:\deep_learning\robot_footballista_quera\train"
dataset = FootballistaDataset(base_path, transform=transform)
train_dataset, val_dataset = split_dataset(dataset, train_size=0.8)

train_loader = DataLoader(train_dataset, batch_size=5, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=5, shuffle=False)

# %%
train_labels = [dataset.labels[i] for i in train_dataset.indices]
val_labels = [dataset.labels[i] for i in val_dataset.indices]
for cls in dataset.classes:
    train_count = train_labels.count(dataset.classes.index(cls))
    val_count = val_labels.count(dataset.classes.index(cls))
    print(f"{cls} - Train: {train_count}, val: {val_count}")
print('*****************************************')
for batch in train_loader:
    images, labels = batch
    print(f"Train batch - Images shape: {images.shape}, Labels: {labels}")
    break
for batch in val_loader:
    images, labels = batch
    print(f"Val batch - Images shape: {images.shape}, Labels: {labels}")
    break
# Out:
# Defender - Train: 89, val: 22
# Forward - Train: 82, val: 21
# Goalkeeper - Train: 53, val: 14
# Midfielder - Train: 93, val: 23
# *****************************************
# Train batch - Images shape: torch.Size([5, 3, 224, 224]), Labels: tensor([2, 0, 2, 2, 2])
# Val batch - Images shape: torch.Size([5, 3, 224, 224]), Labels: tensor([1, 1, 1, 0, 2])

# %%
clip_vision_model = CLIPVisionModel.from_pretrained("openai/clip-vit-base-patch16").to(device)

class CLIPClassifier(nn.Module):
    def __init__(self, clip_vision_model, num_classes):
        super().__init__()
        self.clip_vision_model = clip_vision_model
        for param in self.clip_vision_model.parameters():
            param.requires_grad = True
        
        hidden_dim = clip_vision_model.config.hidden_size

        self.classifier = nn.Sequential(
            nn.Linear(hidden_dim, 256),
            nn.LayerNorm(256),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(256, 128),
            nn.LayerNorm(128),
            nn.ReLU(),
            nn.Dropout(0.3),

            nn.Linear(128, num_classes)
            )


    def forward(self, pixel_values):
        outputs = self.clip_vision_model(pixel_values=pixel_values)
        image_features = outputs.pooler_output 
        logits = self.classifier(image_features)
        return logits

model = CLIPClassifier(clip_vision_model, num_classes=4).to(device)
for name, param in model.named_parameters():
    print(name, param.requires_grad)
# Out:
# clip_vision_model.vision_model.embeddings.class_embedding True
# clip_vision_model.vision_model.embeddings.patch_embedding.weight True
# clip_vision_model.vision_model.embeddings.position_embedding.weight True
# clip_vision_model.vision_model.pre_layrnorm.weight True
# clip_vision_model.vision_model.pre_layrnorm.bias True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.0.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.0.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.0.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.0.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.0.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.0.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.0.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.0.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.0.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.1.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.1.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.1.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.1.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.1.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.1.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.1.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.1.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.1.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.2.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.2.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.2.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.2.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.2.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.2.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.2.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.2.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.2.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.3.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.3.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.3.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.3.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.3.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.3.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.3.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.3.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.3.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.4.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.4.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.4.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.4.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.4.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.4.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.4.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.4.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.4.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.5.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.5.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.5.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.5.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.5.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.5.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.5.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.5.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.5.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.6.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.6.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.6.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.6.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.6.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.6.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.6.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.6.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.6.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.7.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.7.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.7.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.7.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.7.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.7.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.7.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.7.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.7.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.8.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.8.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.8.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.8.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.8.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.8.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.8.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.8.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.8.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.9.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.9.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.9.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.9.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.9.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.9.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.9.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.9.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.9.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.10.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.10.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.10.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.10.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.10.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.10.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.10.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.10.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.10.layer_norm2.bias True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.k_proj.weight True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.k_proj.bias True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.v_proj.weight True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.v_proj.bias True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.q_proj.weight True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.q_proj.bias True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.out_proj.weight True
# clip_vision_model.vision_model.encoder.layers.11.self_attn.out_proj.bias True
# clip_vision_model.vision_model.encoder.layers.11.layer_norm1.weight True
# clip_vision_model.vision_model.encoder.layers.11.layer_norm1.bias True
# clip_vision_model.vision_model.encoder.layers.11.mlp.fc1.weight True
# clip_vision_model.vision_model.encoder.layers.11.mlp.fc1.bias True
# clip_vision_model.vision_model.encoder.layers.11.mlp.fc2.weight True
# clip_vision_model.vision_model.encoder.layers.11.mlp.fc2.bias True
# clip_vision_model.vision_model.encoder.layers.11.layer_norm2.weight True
# clip_vision_model.vision_model.encoder.layers.11.layer_norm2.bias True
# clip_vision_model.vision_model.post_layernorm.weight True
# clip_vision_model.vision_model.post_layernorm.bias True
# classifier.0.weight True
# classifier.0.bias True
# classifier.1.weight True
# classifier.1.bias True
# classifier.4.weight True
# classifier.4.bias True
# classifier.5.weight True
# classifier.5.bias True
# classifier.8.weight True
# classifier.8.bias True

# %%
def train_model(model, train_loader, val_loader, optimizer, criterion, device, num_epochs):
    train_losses, val_losses = [], []
    train_accuracies, val_accuracies = [], []

    best_val_acc = 0.0   

    scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(
        optimizer, mode='max', factor=0.5, patience=2, verbose=True
    )

    for epoch in range(num_epochs):
        print(f"\nEpoch {epoch+1}/{num_epochs}")

        # --- Training ---
        model.train()
        train_loss, correct_preds, total_preds = 0, 0, 0

        for batch in tqdm(train_loader, desc="Training", leave=False):
            pixel_values, labels = batch
            pixel_values = pixel_values.to(device)
            labels = labels.to(device)

            optimizer.zero_grad()
            outputs = model(pixel_values)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            preds = outputs.argmax(dim=1)
            correct_preds += (preds == labels).sum().item()
            total_preds += labels.size(0)

        epoch_train_loss = train_loss / len(train_loader)
        epoch_train_acc = correct_preds / total_preds
        train_losses.append(epoch_train_loss)
        train_accuracies.append(epoch_train_acc)

        # --- Validation ---
        model.eval()
        val_loss, correct_preds, total_preds = 0, 0, 0

        with torch.no_grad():
            for batch in tqdm(val_loader, desc="Validation", leave=False):
                pixel_values, labels = batch
                pixel_values = pixel_values.to(device)
                labels = labels.to(device)

                outputs = model(pixel_values)
                loss = criterion(outputs, labels)

                val_loss += loss.item()
                preds = outputs.argmax(dim=1)
                correct_preds += (preds == labels).sum().item()
                total_preds += labels.size(0)

        epoch_val_loss = val_loss / len(val_loader)
        epoch_val_acc = correct_preds / total_preds
        val_losses.append(epoch_val_loss)
        val_accuracies.append(epoch_val_acc)

        print(f"Train Loss: {epoch_train_loss:.4f} | Train Acc: {epoch_train_acc:.4f} | "
              f"Val Loss: {epoch_val_loss:.4f} | Val Acc: {epoch_val_acc:.4f}")

        if epoch_val_acc > best_val_acc:
            best_val_acc = epoch_val_acc
            torch.save(model.state_dict(), "best_model.pth")
            print("=> Saved best model weights")

        scheduler.step(epoch_val_acc)

    epochs_range = range(1, num_epochs + 1)
    plt.figure(figsize=(12, 5))

    plt.subplot(1, 2, 1)
    plt.plot(epochs_range, train_losses, label='Train Loss')
    plt.plot(epochs_range, val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss over epochs')
    plt.legend()

    plt.subplot(1, 2, 2)
    plt.plot(epochs_range, train_accuracies, label='Train Accuracy')
    plt.plot(epochs_range, val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.title('Accuracy over epochs')
    plt.legend()

    plt.show()

    return train_losses, val_losses, train_accuracies, val_accuracies

# %%
model = CLIPClassifier(clip_vision_model, num_classes=4).to(device)

train_loader = DataLoader(train_dataset, batch_size=5, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=5, shuffle=False)

optimizer = optim.Adam(model.classifier.parameters(), lr=1e-4)

criterion = nn.CrossEntropyLoss()

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

num_epochs = 10 

train_losses, val_losses, train_accuracies, val_accuracies = train_model(
    model=model,
    train_loader=train_loader,
    val_loader=val_loader,
    optimizer=optimizer,
    criterion=criterion,
    device=device,
    num_epochs=num_epochs
)

# %%
model.load_state_dict(torch.load("best_model.pth"))
model.eval()

# %%
def predict(model, folder_path, transform, device):
    model.eval()
    results = []

    classes = ['Defender', 'Forward', 'Goalkeeper', 'Midfielder']

    files = [f for f in os.listdir(folder_path) if f.endswith('.jpg')]

    def extract_number(f):
        match = re.match(r"(\d+)\.jpg", f)
        return int(match.group(1)) if match else float('inf')
    files = sorted(files, key=extract_number)

    with torch.no_grad():
        for file in files:
            image_path = os.path.join(folder_path, file)
            image = np.array(Image.open(image_path).convert("RGB"))
            image = transform(image=image)["image"].unsqueeze(0).to(device)

            outputs = model(image)
            preds = outputs.argmax(dim=1).cpu().item()
            pred_class = classes[preds]

            results.append(pred_class) 

    df = pd.DataFrame(results, columns=["Position"])
    return df

# %%
df = predict(model, folder_path="/content/folder/test", transform=transform, device=device)
df.to_csv("submission.csv", index=False)

# %%
df
